# %% [markdown]
# # Logistic Regression Model with Custom Dataset
# ## Includes Dataset Preprocessing

# %%
import time

import findspark
findspark.init()
import pyspark
import numpy as np
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DoubleType, DateType
from pyspark.ml.feature import HashingTF, IDF, Tokenizer, StringIndexer, CountVectorizer, NGram, VectorAssembler, ChiSqSelector
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

from pyspark.ml import Transformer
from pyspark.sql import DataFrame
from pyspark.ml.feature import StopWordsRemover
import re

# %% [markdown]
# ## Context variables and dataset loading

# %%
spark1 = SparkSession.builder\
            .master("local[16]")\
            .appName("TOT") \
            .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/05 18:40:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
path = "hdfs://localhost:9000/sentiment/raw/"

schema = StructType([
    StructField("target", IntegerType(), True),
    StructField("id", StringType(), True),
    StructField("date", StringType(), True),
    StructField("query", StringType(), True),
    StructField("author", StringType(), True),
    StructField("tweet", StringType(), True)])

df = spark1.read.csv(path,
                     header=False,
                     schema=schema)
df = df.dropna()

# %%
"""
Class inheriting from PySpark Transformer to be usable in a pipeline or with a classname.transform(dataset)

__init__:
Initializes column names and the regular expression used to filter out unwanted URLs and punctuation marks.

_transform:
Applyes the transformation to a given dataset.

Note: The process is not well optimized and will take longer to complete, but it will improve accuracy.
"""
class WordFormatter(Transformer):
    def __init__(self, *, inputCol, outputCol):

        super(WordFormatter, self).__init__()
        self.regpat = re.compile(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b')
        self.ponc = [',', '.', '?', '-']
        self.inputCol = inputCol
        self.outputCol = outputCol

    def stopw(self, wt):

        filtered_sentence = []

        # pour tout les mots
        for w in wt["filtered"]:
            wrd = w.strip().lower()

            # on vérifie si la ponctuation non désirée est présente, on l'enlève si oui
            for char in self.ponc:
                wrd = wrd.replace(char, '')

            # on ne garde pas les mots avec un URL, mot vide, mot ' ' ou des mots avec '@'
            if not re.fullmatch(self.regpat, wrd) and wrd != ' ' and wrd != '' and '@' not in wrd:
                filtered_sentence.append(wrd)

        # renvoie la ligne telle qu'elle était mais avec notre liste en plus
        return wt[0], wt[1], wt[2], wt[3], wt[4], wt[5], wt[6], filtered_sentence

    def _transform(self, dtf: DataFrame) -> DataFrame:

        # applique le stop words de PySpark
        rem = StopWordsRemover(inputCol=self.inputCol, outputCol="filtered")
        ndtf = rem.transform(dtf)

        # applique notre fonction en plus pour mieux filtrer
        rdd = ndtf.rdd.map(lambda x: self.stopw(x))
        ndtf = rdd.toDF()

        # remets les noms de colonne de départ
        official_col = ['target', 'id', 'date', 'query', 'author', 'tweet', self.inputCol, self.outputCol]

        for old, new in zip(ndtf.columns, official_col):
            ndtf = ndtf.withColumnRenamed(old, new)

        return ndtf

# %%
(train_set, test_set) = df.randomSplit([0.80, 0.20], seed = 2000)

# %% [markdown]
# ## HashingTF - IDF (paramètres par défaut)

# %%
tokenizer = Tokenizer(inputCol="tweet", outputCol="tk")
wordform = WordFormatter(inputCol="tk", outputCol="words")
hashtf = HashingTF(inputCol="words", outputCol='tf')
idf = IDF(inputCol='tf', outputCol="features")

label_stringIdx = StringIndexer(inputCol = "target", outputCol = "label")

lr = LogisticRegression()
evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")

pipeline = Pipeline(stages=[tokenizer, wordform, hashtf, idf, label_stringIdx, lr])

# %% [markdown]
# ## HashingTF - IDF (paramètres customisés)

# %%
tokenizer = Tokenizer(inputCol="tweet", outputCol="tk")
wordform = WordFormatter(inputCol="tk", outputCol="words")
hashtf = HashingTF(numFeatures=2**16, inputCol="words", outputCol='tf')
idf = IDF(inputCol='tf', outputCol="features", minDocFreq=5) #minDocFreq: remove sparse terms

label_stringIdx = StringIndexer(inputCol = "target", outputCol = "label")

lr = LogisticRegression()
evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")

pipeline = Pipeline(stages=[tokenizer, wordform, hashtf, idf, label_stringIdx, lr])

# %% [markdown]
# ## CountVectorizer - IDF (paramètres par défaut)

# %%
tokenizer = Tokenizer(inputCol="tweet", outputCol="tk")
wordform = WordFormatter(inputCol="tk", outputCol="words")
cv = CountVectorizer(inputCol="words", outputCol='cv')
idf = IDF(inputCol='cv', outputCol="features")

label_stringIdx = StringIndexer(inputCol = "target", outputCol = "label")

lr = LogisticRegression()
evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")

pipeline = Pipeline(stages=[tokenizer, wordform, cv, idf, label_stringIdx, lr])

# %% [markdown]
# ## CountVectorizer - IDF (paramètres customisés)

# %%
tokenizer = Tokenizer(inputCol="tweet", outputCol="tk")
wordform = WordFormatter(inputCol="tk", outputCol="words")
cv = CountVectorizer(vocabSize=2**16, inputCol="words", outputCol='cv')
idf = IDF(inputCol='cv', outputCol="features", minDocFreq=5) #minDocFreq: remove sparse terms

label_stringIdx = StringIndexer(inputCol = "target", outputCol = "label")

lr = LogisticRegression()
evaluator = MulticlassClassificationEvaluator(predictionCol="prediction")

pipeline = Pipeline(stages=[tokenizer, wordform, cv, idf, label_stringIdx, lr])

# %% [markdown]
# # CountVectorizer + NGram + ChisQSelector

# %%
def build_trigrams(inputCol=["tweet","target"], n=3):
    
    tokenizer = [Tokenizer(inputCol="tweet", outputCol="tk")]
    wordform = [WordFormatter(inputCol="tk", outputCol="words")]

    ngrams = [
        NGram(n=i, inputCol="words", outputCol="{0}_grams".format(i))
        for i in range(1, n + 1)
    ]

    cv = [
        CountVectorizer(vocabSize=2**14,inputCol="{0}_grams".format(i),
            outputCol="{0}_tf".format(i))
        for i in range(1, n + 1)
    ]
    
    idf = [IDF(inputCol="{0}_tf".format(i), outputCol="{0}_tfidf".format(i), minDocFreq=5) for i in range(1, n + 1)]

    assembler = [VectorAssembler(
        inputCols=["{0}_tfidf".format(i) for i in range(1, n + 1)],
        outputCol="rawFeatures"
    )]
    
    label_stringIdx = [StringIndexer(inputCol = "target", outputCol = "label")]
    
    selector = [ChiSqSelector(numTopFeatures=2**14,featuresCol='rawFeatures', outputCol="features")]
    
    lr = [LogisticRegression()]
    
    return Pipeline(stages=tokenizer + wordform + ngrams + cv + idf + assembler + label_stringIdx + selector + lr)

# %%
# %%time
pipelineFit = build_trigrams().fit(train_set)

predictions = pipelineFit.transform(test_set)

accuracy = evaluator.evaluate(predictions, {evaluator.metricName: "accuracy"})
precision = evaluator.evaluate(predictions, {evaluator.metricName: "weightedPrecision"})
recall = evaluator.evaluate(predictions, {evaluator.metricName: "weightedRecall"})

# Print the results
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_1 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_1 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_13 in memory! (computed 1025.6 KiB so far)
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_12 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_12 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_12 to disk instead.
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_13 to disk instead.
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_1 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_4 in memory! (computed 1024.4 KiB so far)
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_3 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_3 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_10 in memory! (computed 3.4 MiB so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_3 to disk instead.
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_10 to disk instead.
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_4 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_0 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_0 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_0 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_11 in memory! (computed 18.4 MiB so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_11 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_14 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_14 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_14 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_8 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_8 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_8 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_7 in memory! (computed 3.4 MiB so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_7 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_5 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_27_2 in memory.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_5 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_2 in memory! (computed 504.0 B so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_5 to disk instead.
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_2 to disk instead.
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_15 in memory! (computed 5.2 MiB so far)
# 26/01/05 18:43:14 WARN MemoryStore: Not enough space to cache rdd_27_9 in memory! (computed 2.3 MiB so far)
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_15 to disk instead.
# 26/01/05 18:43:14 WARN BlockManager: Persisting block rdd_27_9 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_8 in memory! (computed 12.6 MiB so far)
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_3 in memory! (computed 8.2 MiB so far)
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_11 in memory! (computed 5.5 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_11 to disk instead.
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_8 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_1 in memory! (computed 28.8 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_1 to disk instead.
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_3 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_5 in memory! (computed 29.0 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_5 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_7 in memory! (computed 28.4 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_7 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_9 in memory! (computed 8.0 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_9 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_12 in memory! (computed 32.6 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_12 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_10 in memory! (computed 28.6 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_10 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_4 in memory! (computed 19.3 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_4 to disk instead.
# 26/01/05 18:44:00 WARN MemoryStore: Not enough space to cache rdd_36_0 in memory! (computed 28.6 MiB so far)
# 26/01/05 18:44:00 WARN BlockManager: Persisting block rdd_36_0 to disk instead.
# 26/01/05 18:44:02 WARN MemoryStore: Not enough space to cache rdd_36_4 in memory! (computed 12.9 MiB so far)
# 26/01/05 18:44:02 WARN MemoryStore: Not enough space to cache rdd_36_9 in memory! (computed 13.0 MiB so far)
# 26/01/05 18:44:02 WARN MemoryStore: Not enough space to cache rdd_36_11 in memory! (computed 5.8 MiB so far)
# 26/01/05 18:44:02 WARN MemoryStore: Not enough space to cache rdd_36_8 in memory! (computed 8.6 MiB so far)
# 26/01/05 18:44:02 WARN MemoryStore: Not enough space to cache rdd_36_3 in memory! (computed 19.6 MiB so far)
# 26/01/05 18:44:02 WARN MemoryStore: Not enough space to cache rdd_36_9 in memory! (computed 3.7 MiB so far)
# 26/01/05 18:44:03 WARN MemoryStore: Not enough space to cache rdd_36_11 in memory! (computed 8.7 MiB so far)
# 26/01/05 18:44:03 WARN MemoryStore: Not enough space to cache rdd_36_4 in memory! (computed 3.7 MiB so far)
# 26/01/05 18:44:03 WARN MemoryStore: Not enough space to cache rdd_36_8 in memory! (computed 8.6 MiB so far)
# 26/01/05 18:44:03 WARN MemoryStore: Not enough space to cache rdd_36_3 in memory! (computed 13.1 MiB so far)
# 26/01/05 18:45:59 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# Traceback (most recent call last):
#   File "/opt/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 233, in manager
#     code = worker(sock, authenticated)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/spark/python/lib/pyspark.zip/pyspark/daemon.py", line 87, in worker
#     outfile.flush()
# BrokenPipeError: [Errno 32] Broken pipe
# 26/01/05 18:46:01 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/01/05 18:46:41 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 26/01/05 18:47:51 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 26/01/05 18:47:52 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:48:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:48:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:48:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:33 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:33 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:33 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:34 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:34 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:35 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:35 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:35 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:36 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:36 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:37 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:37 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:38 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:38 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:38 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:39 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:39 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:39 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:40 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:40 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:40 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:41 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:41 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:41 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:42 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:42 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:42 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:43 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:43 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:43 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:45 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:45 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:46 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:46 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:47 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:47 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:47 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:48 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:48 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:48 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:49 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:49 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:50 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:50 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:50 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:51 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:51 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:51 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:52 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:52 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:52 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:53 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:53 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:53 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:54 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:54 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:54 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:55 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:55 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:55 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:56 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:56 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:56 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:57 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:57 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:58 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:58 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:58 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:59 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:59 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:49:59 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:00 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:00 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:01 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:01 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:02 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:02 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:02 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:03 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:03 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:03 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:04 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:04 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:04 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:05 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:05 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:05 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:06 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:06 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:07 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:07 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:08 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:08 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:08 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:09 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:09 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:10 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:10 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:10 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:11 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:11 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:11 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:12 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:12 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:12 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:13 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:13 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:13 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:14 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:14 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:14 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:15 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:16 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:16 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:16 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:17 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:17 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:18 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:18 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:18 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:19 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:19 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:19 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:20 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:20 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:20 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:21 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:21 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:21 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:22 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:22 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:22 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:23 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:23 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:23 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:24 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:24 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:25 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:25 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:25 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:26 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:26 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:26 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:27 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:27 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:27 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:28 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:28 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:28 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:29 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:29 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:30 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:30 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:30 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:31 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:31 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:32 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:32 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:32 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:33 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:33 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:33 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:34 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:34 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:34 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:35 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:35 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:36 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:36 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:36 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:37 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:37 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:37 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:38 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:38 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:38 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:39 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:39 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:40 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:40 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:40 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:41 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:41 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:41 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:42 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:42 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:42 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:43 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:43 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:44 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:45 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:45 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:45 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:46 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:46 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:46 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:47 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:47 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:47 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:48 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:48 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:48 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:49 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:49 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:50 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:50 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:50 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:51 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:51 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:51 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:52 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:52 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:53 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:53 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:53 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:54 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:54 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:54 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:55 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:55 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:56 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:56 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:56 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:57 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:57 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:57 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:58 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:58 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:58 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:59 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:59 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:50:59 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:00 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:00 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:00 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:01 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:01 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:01 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:02 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:02 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:02 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:03 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:03 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:04 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:04 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:04 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:05 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:05 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:06 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:06 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:06 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:07 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:07 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:07 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:08 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:08 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:08 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:09 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:09 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:10 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:10 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:10 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:11 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:11 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:11 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:12 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:12 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:12 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:13 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:13 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:13 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:14 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:14 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:14 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:15 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:15 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:15 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:16 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:16 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:17 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:17 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:17 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:18 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:18 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:19 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:19 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:19 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:20 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:20 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:21 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:21 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:21 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:22 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:22 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:22 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:23 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:23 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:23 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:24 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:24 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:24 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:25 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:25 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:25 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:26 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:26 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:26 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:27 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:27 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 26/01/05 18:51:29 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/01/05 18:51:44 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 26/01/05 18:51:57 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# [Stage 356:=========================================>             (12 + 4) / 16]
# Accuracy: 0.7795438019417597
# Precision: 0.7810304029174993
# Recall: 0.7795438019417597
# CPU times: user 835 ms, sys: 204 ms, total: 1.04 s
# Wall time: 10min 3s

# %%
df.write.mode("overwrite").option("header", True).csv("/home/hung/Workspace/University/DLL-IS330/twitter-sentiment-analysis-pyspark/df_clean")
